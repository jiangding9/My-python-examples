# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-40, 10, 100)  #在0-20的长度上获取5个等距的点。
y1 = 0.60 * x + 60.37
y2 = 0.12 * x + 47.55

# %%
plt.plot(x, y1)
plt.plot(x, y2)

x0 = -26.708
y0 = 44.345

plt.scatter(x0, y0, s=200, c = 'r')

plt.axvline(x=0, color='red', linestyle='--')  #设置参考线

plt.xlabel('$ΔH_P$', fontsize=15, fontname='Times New Roman')  #给出X轴的注释,同时设置字体大小和类型
plt.ylabel('$E_P^ass$', fontsize=15, fontname='Times New Roman') 

plt.savefig('/Users/Administrator.DESKTOP-CDML10A/Desktop/image1.tiff', dpi = 360)
